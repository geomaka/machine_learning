# %%
from matplotlib import pyplot as plt
import numpy as np

x,y, scale = np.random.randn(3,100)
fig, ax = plt.subplots()

sc = ax.scatter(x=x,y=y,c=scale, s=np.abs(scale)*500)
plt.colorbar(sc)
ax.set(title="Some random data")
plt.show()
